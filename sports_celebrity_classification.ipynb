# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %% [markdown]
# Special thanks to Debjyoti Paul (My data scientist friend at Amazon) for help with this project

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test/Maria Sharapova Shows off Toned Body.jpg')
img.shape
img
# Out:
# array([[[255, 245, 241],
#         [255, 245, 241],
#         [255, 245, 241],
#         ...,
#         [255, 245, 241],
#         [255, 245, 241],
#         [255, 245, 241]],
#
#        [[255, 245, 241],
#         [255, 245, 241],
#         [255, 245, 241],
#         ...,
#         [255, 245, 241],
#         [255, 245, 241],
#         [255, 245, 241]],
#
#        [[255, 245, 241],
#         [255, 245, 241],
#         [255, 245, 241],
#         ...,
#         [255, 245, 241],
#         [255, 245, 241],
#         [255, 245, 241]],
#
#        ...,
#
#        [[233, 207, 193],
#         [233, 207, 193],
#         [234, 207, 193],
#         ...,
#         [168, 182, 224],
#         [165, 181, 223],
#         [164, 180, 222]],
#
#        [[232, 206, 192],
#         [232, 206, 192],
#         [233, 206, 192],
#         ...,
#         [167, 181, 223],
#         [164, 180, 222],
#         [163, 179, 221]],
#
#        [[232, 206, 192],
#         [232, 206, 192],
#         [233, 206, 192],
#         ...,
#         [163, 177, 219],
#         [160, 176, 218],
#         [160, 176, 218]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
im  = cv2.resize(img,(128,128))

# %%
plt.imshow(im)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (1065, 1110)

# %%
gray[0]
# Out:
# array([245, 245, 245, ..., 245, 245, 245], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[517, 174, 349, 349]], dtype=int32)

# %%
eye_cascade
# Out:
# <CascadeClassifier 0x7fd5e0052950>

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (517, 174, 349, 349)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(25,255,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color)

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (349, 349, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
# plt.imshow(im_har, cmap='gray')
plt.imshow(im_har)

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    a =[]
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            a.append(roi_color)
    return a

# %%
aa =get_cropped_image_if_2_eyes('./train/86989484.jpg')
plt.imshow(aa[1])

# %%
import scipy.spatial as sp
import os
a = cv2.imread('train/cropped/lionel messi - Google Search/lionel messi - Google Search1.png')
a =cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
a  = cv2.resize(a, (200, 200),
               interpolation = cv2.INTER_NEAREST)
for i in os.listdir('train/cropped/lionel messi - Google Search'):
    b = cv2.imread('train/cropped/lionel messi - Google Search/' + i)
    b = cv2.cvtColor(b, cv2.COLOR_BGR2GRAY)
    b = cv2.resize(b, (200, 200),
               interpolation = cv2.INTER_NEAREST)
    
    c  = 1 - sp.distance.cdist(a,b, 'cosine')
    
    print(sum(sum(c))/(200*200))
# Out:
# 0.8801226155372535
# 0.8384010248833678
# 0.8668365389816947
# 0.8879355957897563
# 0.8841432102039144
# 0.878221341708338
# 0.8871660115062816
# 0.8698594334848682
# 0.8618662499292951
# 0.8784328583289615
# 0.8842386865778097
# 0.864224747145315
# 0.8681735707186781
# 0.8833795182390443
# 0.8385202067954526
# 0.885916390982804
# 0.843517330386478
# 0.8312040331315215
# 0.8945008410714274
# 0.9045285928200177
# 0.865977567365657
# 0.8820192151360008
# 0.8759129425330593
# 0.8756864677895766

# %%
import cv2
d= cv2.imread('/train/cropped/roger federer - Google Search/roger federer - Google Search6.png')
d
# Out:
# [ WARN:0@0.067] global /io/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('/train/cropped/roger federer - Google Search/roger federer - Google Search6.png'): can't open/read file: check file path/integrity

# %%
original_image = cv2.imread('./test/Maria Sharapova Shows off Toned Body.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test/Maria Sharapova Shows off Toned Body.jpg')
plt.imshow(cropped_image)

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test/Photos_ Happy Birthday Roger Federer.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes('./test/Photos_ Happy Birthday Roger Federer.jpg')
cropped_image_no_2_eyes

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./train/"
path_to_cr_data = "./train/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./train/maria sharapova - Google Search',
#  './train/serena williams - Google Search',
#  './train/virat kohli - Google Search',
#  './train/roger federer - Google Search',
#  './train/lionel messi - Google Search']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        if entry is None:
            continue
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./train/cropped/maria sharapova - Google Search
# Generating cropped images in folder:  ./train/cropped/serena williams - Google Search
# Generating cropped images in folder:  ./train/cropped/virat kohli - Google Search
# Generating cropped images in folder:  ./train/cropped/roger federer - Google Search
# Generating cropped images in folder:  ./train/cropped/lionel messi - Google Search

# %% [markdown]
# ### Now you should have cropped folder under datasets folder that contains cropped images

# %% [markdown]
# ### Manually examine cropped folder and delete any unwanted images

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'maria sharapova - Google Search': ['./train/cropped/maria sharapova - Google Search/maria sharapova - Google Search14.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search12.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search10.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search15.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search4.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search3.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search1.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search8.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search13.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search6.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search2.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search17.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search9.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search5.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search16.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search11.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search18.png',
#   './train/cropped/maria sharapova - Google Search/maria sharapova - Google Search7.png'],
#  'serena williams - Google Search': ['./train/cropped/serena williams - Google Search/serena williams - Google Search2.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search7.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search9.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search8.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search1.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search5.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search4.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search10.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search6.png',
#   './train/cropped/serena williams - Google Search/serena williams - Google Search3.png'],
#  'virat kohli - Google Search': ['./train/cropped/virat kohli - Google Search/virat kohli - Google Search5.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search13.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search4.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search8.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search19.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search18.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search11.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search14.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search6.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search7.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search17.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search16.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search3.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search15.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search12.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search2.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search9.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search10.png',
#   './train/cropped/virat kohli - Google Search/virat kohli - Google Search1.png'],
#  'roger federer - Google Search': ['./train/cropped/roger federer - Google Search/roger federer - Google Search1.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search7.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search5.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search2.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search6.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search3.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search4.png',
#   './train/cropped/roger federer - Google Search/roger federer - Google Search8.png'],
#  'lionel messi - Google Search': ['./train/cropped/lionel messi - Google Search/lionel messi - Google Search24.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search21.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search6.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search18.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search22.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search19.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search5.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search9.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search20.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search13.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search11.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search17.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search8.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search1.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search4.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search3.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search12.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search16.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search14.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search15.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search10.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search2.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search7.png',
#   './train/cropped/lionel messi - Google Search/lionel messi - Google Search23.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'maria sharapova - Google Search': 0,
#  'serena williams - Google Search': 1,
#  'virat kohli - Google Search': 2,
#  'roger federer - Google Search': 3,
#  'lionel messi - Google Search': 4}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[243],
#        [242],
#        [237],
#        ...,
#        [  9],
#        [228],
#        [174]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (79, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         3
#            1       0.33      0.33      0.33         3
#            2       1.00      1.00      1.00         4
#            3       0.00      0.00      0.00         2
#            4       0.86      0.75      0.80         8
#
#     accuracy                           0.70        20
#    macro avg       0.54      0.62      0.56        20
# weighted avg       0.67      0.70      0.67        20
# /home/venugoapal/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/venugoapal/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/venugoapal/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.695455
# 1        random_forest    0.592424
# 2  logistic_regression    0.675758
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.7

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.4

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[3, 0, 0, 0, 0],
#        [1, 1, 0, 0, 1],
#        [0, 0, 4, 0, 0],
#        [1, 0, 0, 1, 0],
#        [1, 1, 0, 1, 5]])

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'maria sharapova - Google Search': 0,
#  'serena williams - Google Search': 1,
#  'virat kohli - Google Search': 2,
#  'roger federer - Google Search': 3,
#  'lionel messi - Google Search': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in /home/venugoapal/anaconda3/lib/python3.8/site-packages (1.0.1)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
